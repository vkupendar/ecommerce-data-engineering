# %%
# %python
print(spark)

# %%
# %python
df=spark.range(5)
df.show()
# Out:
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# |  3|
# |  4|
# +---+

# %%
# %python

df_orders=spark.read.csv("/Volumes/de_project/ecommerce_db/ecommerce/csvfiles/olist_orders_dataset.csv",header=True,inferSchema=True)

# %%
# %python
print(df_orders)
# Out:
# DataFrame[order_id: string, customer_id: string, order_status: string, order_purchase_timestamp: timestamp, order_approved_at: timestamp, order_delivered_carrier_date: timestamp, order_delivered_customer_date: timestamp, order_estimated_delivery_date: timestamp]

# %%
# %python
df_orders.show()
# Out:
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |            order_id|         customer_id|order_status|order_purchase_timestamp|  order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |e481f51cbdc54678b...|9ef432eb625129730...|   delivered|     2017-10-02 10:56:33|2017-10-02 11:07:15|         2017-10-04 19:55:00|          2017-10-10 21:25:13|          2017-10-18 00:00:00|
# |53cdb2fc8bc7dce0b...|b0830fb4747a6c6d2...|   delivered|     2018-07-24 20:41:37|2018-07-26 03:24:27|         2018-07-26 14:31:00|          2018-08-07 15:27:45|          2018-08-13 00:00:00|
# ...

# %%
# %python
df_orders.head(5)
# Out:
# [Row(order_id='e481f51cbdc54678b7cc49136f2d6af7', customer_id='9ef432eb6251297304e76186b10a928d', order_status='delivered', order_purchase_timestamp=datetime.datetime(2017, 10, 2, 10, 56, 33), order_approved_at=datetime.datetime(2017, 10, 2, 11, 7, 15), order_delivered_carrier_date=datetime.datetime(2017, 10, 4, 19, 55), order_delivered_customer_date=datetime.datetime(2017, 10, 10, 21, 25, 13), order_estimated_delivery_date=datetime.datetime(2017, 10, 18, 0, 0)),
#  Row(order_id='53cdb2fc8bc7dce0b6741e2150273451', customer_id='b0830fb4747a6c6d20dea0b8c802d7ef', order_status='delivered', order_purchase_timestamp=datetime.datetime(2018, 7, 24, 20, 41, 37), order_approved_at=datetime.datetime(2018, 7, 26, 3, 24, 27), order_delivered_carrier_date=datetime.datetime(2018, 7, 26, 14, 31), order_delivered_customer_date=datetime.datetime(2018, 8, 7, 15, 27, 45), order_estimated_delivery_date=datetime.datetime(2018, 8, 13, 0, 0)),
# ...

# %%
# %python
df_orders.count()
# Out:
# 99441

# %%
# %python
df_orders.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- order_purchase_timestamp: timestamp (nullable = true)
#  |-- order_approved_at: timestamp (nullable = true)
#  |-- order_delivered_carrier_date: timestamp (nullable = true)
#  |-- order_delivered_customer_date: timestamp (nullable = true)
#  |-- order_estimated_delivery_date: timestamp (nullable = true)

# %%
# %python
df_orders.columns
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'order_purchase_timestamp',
#  'order_approved_at',
#  'order_delivered_carrier_date',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date']

# %%
# %python
df_orders.count()
# Out:
# 99441

# %%
# %python
df_orders.select("order_id").distinct().count()
# Out:
# 99441

# %%
from pyspark.sql.functions import col, count, when
df_orders.select([
    count(when(col(c).isNull(), c)).alias(c)
    for c in df_orders.columns
]).show()
# Out:
# +--------+-----------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+
# |order_id|customer_id|order_status|order_purchase_timestamp|order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|
# +--------+-----------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+
# |       0|          0|           0|                       0|              160|                        1783|                         2965|                            0|
# +--------+-----------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+

# %%
df_customers=spark.read.csv("/Volumes/de_project/ecommerce_db/ecommerce/csvfiles/olist_customers_dataset.csv",inferSchema=True,header=True)
df_customers
# Out:
# DataFrame[customer_id: string, customer_unique_id: string, customer_zip_code_prefix: int, customer_city: string, customer_state: string]

# %%
df_customers.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: integer (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)

# %%
df_customers.count()
# Out:
# 99441

# %%
df_customers.show(5)
# Out:
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |         customer_id|  customer_unique_id|customer_zip_code_prefix|       customer_city|customer_state|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |06b8999e2fba1a1fb...|861eff4711a542e4b...|                   14409|              franca|            SP|
# |18955e83d337fd6b2...|290c77bc529b7ac93...|                    9790|sao bernardo do c...|            SP|
# |4e7b3e00288586ebd...|060e732b5b29e8181...|                    1151|           sao paulo|            SP|
# |b2b6027bc5c5109e5...|259dac757896d24d7...|                    8775|     mogi das cruzes|            SP|
# |4f2d8ab171c80ec83...|345ecd01c38d18a90...|                   13056|            campinas|            SP|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# only showing top 5 rows

# %%
df_customers.select("customer_id").distinct().count()
# Out:
# 99441

# %%
from pyspark.sql.functions import col, count, when
df_customers.select([
    count(when(col(c).isNull(), c)).alias(c)
    for c in df_customers.columns
]).show()
# Out:
# +-----------+------------------+------------------------+-------------+--------------+
# |customer_id|customer_unique_id|customer_zip_code_prefix|customer_city|customer_state|
# +-----------+------------------+------------------------+-------------+--------------+
# |          0|                 0|                       0|            0|             0|
# +-----------+------------------+------------------------+-------------+--------------+

# %%
df_geolocation=spark.read.csv("/Volumes/de_project/ecommerce_db/ecommerce/csvfiles/olist_geolocation_dataset.csv",header=True,inferSchema=True)

# %%
df_geolocation.printSchema()
# Out:
# root
#  |-- geolocation_zip_code_prefix: integer (nullable = true)
#  |-- geolocation_lat: double (nullable = true)
#  |-- geolocation_lng: double (nullable = true)
#  |-- geolocation_city: string (nullable = true)
#  |-- geolocation_state: string (nullable = true)

# %%
df_geolocation.columns
# Out:
# ['geolocation_zip_code_prefix',
#  'geolocation_lat',
#  'geolocation_lng',
#  'geolocation_city',
#  'geolocation_state']

# %%
df_geolocation.count()
# Out:
# 1000163

# %%
df_geolocation.select('geolocation_zip_code_prefix').distinct().count()
# Out:
# 19015

# %%
    from pyspark.sql.functions import col,count, when
    df_geolocation.select([
        F.count(when(col(c).isNull(), c)).alias(c)
        for c in df_geolocation.columns
    ]).show()
# Out:
# +---------------------------+---------------+---------------+----------------+-----------------+
# |geolocation_zip_code_prefix|geolocation_lat|geolocation_lng|geolocation_city|geolocation_state|
# +---------------------------+---------------+---------------+----------------+-----------------+
# |                          0|              0|              0|               0|                0|
# +---------------------------+---------------+---------------+----------------+-----------------+

# %%
df_order_items=spark.read.csv("/Volumes/de_project/ecommerce_db/ecommerce/csvfiles/olist_order_items_dataset.csv",header=True,inferSchema=True)

# %%
df_order_items.printSchema()
print(df_order_items.columns)
print(df_order_items.count())
print(df_order_items.select('order_id').distinct().count())
from pyspark.sql.functions import col,count,when
df_order_items.select([
    count(when(col(c).isNull(), c)).alias(c)
    for c in df_order_items.columns
]).show()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- order_item_id: integer (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- seller_id: string (nullable = true)
#  |-- shipping_limit_date: timestamp (nullable = true)
#  |-- price: double (nullable = true)
#  |-- freight_value: double (nullable = true)
#
# ['order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value']
# 112650
# 98666
# +--------+-------------+----------+---------+-------------------+-----+-------------+
# |order_id|order_item_id|product_id|seller_id|shipping_limit_date|price|freight_value|
# +--------+-------------+----------+---------+-------------------+-----+-------------+
# |       0|            0|         0|        0|                  0|    0|            0|
# +--------+-------------+----------+---------+-------------------+-----+-------------+

# %%
df_order_payments=spark.read.csv("/Volumes/de_project/ecommerce_db/ecommerce/csvfiles/olist_order_payments_dataset.csv",header=True,inferSchema=True)
df_order_payments.printSchema()
print(df_order_payments.columns)
print(df_order_payments.count())
print(df_order_payments.select('order_id').distinct().count())
from pyspark.sql.functions import col,count,when
df_order_payments.select([
    count(when(col(c).isNull(), c)).alias(c)
    for c in df_order_payments.columns
]).show()

display(df_order_payments.head(10))
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- payment_sequential: integer (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- payment_installments: integer (nullable = true)
#  |-- payment_value: double (nullable = true)
#
# ['order_id', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value']
# 103886
# 99440
# +--------+------------------+------------+--------------------+-------------+
# |order_id|payment_sequential|payment_type|payment_installments|payment_value|
# +--------+------------------+------------+--------------------+-------------+
# |       0|                 0|           0|                   0|            0|
# +--------+------------------+------------+--------------------+-------------+
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
# ...
